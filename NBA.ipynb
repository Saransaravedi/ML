# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mlp

# %%
from google.colab import files
data = files.upload()
# Out:
#      <input type="file" id="files-e3c9bd92-1d55-4099-b444-03bca2dc00b1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e3c9bd92-1d55-4099-b444-03bca2dc00b1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
datas = pd.read_csv("nba.csv")

# %%
datas
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1      Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27   5-Jun     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20  10-Jun     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26   3-Jun     203
# 454      Raul Neto       Utah Jazz      25       PG   24   1-Jun     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26   3-Jul     256
# 456    Jeff Withey       Utah Jazz      24        C   26  Jul-00     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
dataset = datas.copy()

# %%
datas.shape
# Out:
# (457, 9)

# %%
datas.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
datas.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1    Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27   5-Jun     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
datas.tail()
# Out:
#              Name       Team  Number Position  Age  Height  Weight   College  \
# 452    Trey Lyles  Utah Jazz      41       PF   20  10-Jun     234  Kentucky
# 453  Shelvin Mack  Utah Jazz       8       PG   26   3-Jun     203    Butler
# 454     Raul Neto  Utah Jazz      25       PG   24   1-Jun     179       NaN
# 455  Tibor Pleiss  Utah Jazz      21        C   26   3-Jul     256       NaN
# 456   Jeff Withey  Utah Jazz      24        C   26  Jul-00     231    Kansas
#
#         Salary
# 452  2239800.0
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0

# %%
datas.iloc[20:26]
# Out:
#                 Name           Team  Number Position  Age  Height  Weight  \
# 20    Sergey Karasev  Brooklyn Nets      10       SG   22   7-Jun     208
# 21   Sean Kilpatrick  Brooklyn Nets       6       SG   26   4-Jun     219
# 22      Shane Larkin  Brooklyn Nets       0       PG   23  11-May     175
# 23       Brook Lopez  Brooklyn Nets      11        C   28  Jul-00     275
# 24  Chris McCullough  Brooklyn Nets       1       PF   21  11-Jun     200
# 25       Willie Reed  Brooklyn Nets      33       PF   26  10-Jun     220
#
#         College      Salary
# 20          NaN   1599840.0
# 21   Cincinnati    134215.0
# 22   Miami (FL)   1500000.0
# 23     Stanford  19689000.0
# 24     Syracuse   1140240.0
# 25  Saint Louis    947276.0

# %%
datas.iloc[7]
# Out:
# Name          Kelly Olynyk
# Team        Boston Celtics
# Number                  41
# Position                 C
# Age                     25
# Height              Jul-00
# Weight                 238
# College            Gonzaga
# Salary           2165160.0
# Name: 7, dtype: object

# %%
datas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    int64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    int64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    int64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB

# %%
datas.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
datas.max()
# Out:
# <ipython-input-15-550251b77d90>:1: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   datas.max()
# Name             Zaza Pachulia
# Team        Washington Wizards
# Number                      99
# Position                    SG
# Age                         40
# Height                  Jun-00
# Weight                     307
# Salary              25000000.0
# dtype: object

# %%
datas.min()
# Out:
# <ipython-input-16-01dafcff4b70>:1: FutureWarning: The default value of numeric_only in DataFrame.min is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   datas.min()
# Name         Aaron Brooks
# Team        Atlanta Hawks
# Number                  0
# Position                C
# Age                    19
# Height              1-Jul
# Weight                161
# Salary            30888.0
# dtype: object

# %%
datas.std()
# Out:
# <ipython-input-17-d4770f4db92a>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   datas.std()
# Number    1.596609e+01
# Age       4.404016e+00
# Weight    2.636834e+01
# Salary    5.229238e+06
# dtype: float64

# %%
datas.count()
# Out:
# Name        457
# Team        457
# Number      457
# Position    457
# Age         457
# Height      457
# Weight      457
# College     373
# Salary      446
# dtype: int64

# %%
datas.isnull()
# Out:
#       Name   Team  Number  Position    Age  Height  Weight  College  Salary
# 0    False  False   False     False  False   False   False    False   False
# 1    False  False   False     False  False   False   False    False   False
# 2    False  False   False     False  False   False   False    False    True
# 3    False  False   False     False  False   False   False    False   False
# 4    False  False   False     False  False   False   False     True   False
# ..     ...    ...     ...       ...    ...     ...     ...      ...     ...
# 452  False  False   False     False  False   False   False    False   False
# 453  False  False   False     False  False   False   False    False   False
# 454  False  False   False     False  False   False   False     True   False
# 455  False  False   False     False  False   False   False     True   False
# 456  False  False   False     False  False   False   False    False   False
#
# [457 rows x 9 columns]

# %%
datas.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
datas.dropna()
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1      Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 3      R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 6    Jordan Mickey  Boston Celtics      55       PF   21   8-Jun     235
# 7     Kelly Olynyk  Boston Celtics      41        C   25  Jul-00     238
# ..             ...             ...     ...      ...  ...     ...     ...
# 449    Rodney Hood       Utah Jazz       5       SG   23   8-Jun     206
# 451  Chris Johnson       Utah Jazz      23       SF   26   6-Jun     206
# 452     Trey Lyles       Utah Jazz      41       PF   20  10-Jun     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26   3-Jun     203
# 456    Jeff Withey       Utah Jazz      24        C   26  Jul-00     231
#
#            College     Salary
# 0            Texas  7730337.0
# ...

# %%
datas.loc[50:55]
# Out:
#                 Name                Team  Number Position  Age  Height  \
# 50      Jerami Grant  Philadelphia 76ers      39       SF   22   8-Jun
# 51    Richaun Holmes  Philadelphia 76ers      22       PF   22  10-Jun
# 52       Carl Landry  Philadelphia 76ers       7       PF   32   9-Jun
# 53  Kendall Marshall  Philadelphia 76ers       5       PG   24   4-Jun
# 54    T.J. McConnell  Philadelphia 76ers      12       PG   24   2-Jun
# 55      Nerlens Noel  Philadelphia 76ers       4       PF   22  11-Jun
#
#     Weight         College     Salary
# 50     210        Syracuse   845059.0
# 51     245   Bowling Green  1074169.0
# 52     248          Purdue  6500000.0
# 53     200  North Carolina  2144772.0
# 54     200         Arizona   525093.0
# 55     228        Kentucky  3457800.0

# %%
datas.iloc[20:26,7]
# Out:
# 20            NaN
# 21     Cincinnati
# 22     Miami (FL)
# 23       Stanford
# 24       Syracuse
# 25    Saint Louis
# Name: College, dtype: object

# %%
datas.iloc[449]
# Out:
# Name        Rodney Hood
# Team          Utah Jazz
# Number                5
# Position             SG
# Age                  23
# Height            8-Jun
# Weight              206
# College            Duke
# Salary        1348440.0
# Name: 449, dtype: object

# %%
datas.iloc[20:26,5:7]
# Out:
#     Height  Weight
# 20   7-Jun     208
# 21   4-Jun     219
# 22  11-May     175
# 23  Jul-00     275
# 24  11-Jun     200
# 25  10-Jun     220

# %%
datas.Height
# Out:
# 0       2-Jun
# 1       6-Jun
# 2       5-Jun
# 3       5-Jun
# 4      10-Jun
#         ...
# 452    10-Jun
# 453     3-Jun
# 454     1-Jun
# 455     3-Jul
# 456    Jul-00
# Name: Height, Length: 457, dtype: object

# %%
datas['Height']
# Out:
# 0       2-Jun
# 1       6-Jun
# 2       5-Jun
# 3       5-Jun
# 4      10-Jun
#         ...
# 452    10-Jun
# 453     3-Jun
# 454     1-Jun
# 455     3-Jul
# 456    Jul-00
# Name: Height, Length: 457, dtype: object

# %%
datas.Name
# Out:
# 0      Avery Bradley
# 1        Jae Crowder
# 2       John Holland
# 3        R.J. Hunter
# 4      Jonas Jerebko
#            ...
# 452       Trey Lyles
# 453     Shelvin Mack
# 454        Raul Neto
# 455     Tibor Pleiss
# 456      Jeff Withey
# Name: Name, Length: 457, dtype: object

# %%
datas.College
# Out:
# 0                  Texas
# 1              Marquette
# 2      Boston University
# 3          Georgia State
# 4                    NaN
#              ...
# 452             Kentucky
# 453               Butler
# 454                  NaN
# 455                  NaN
# 456               Kansas
# Name: College, Length: 457, dtype: object

# %%
datas['Salary']
# Out:
# 0      7730337.0
# 1      6796117.0
# 2            NaN
# 3      1148640.0
# 4      5000000.0
#          ...
# 452    2239800.0
# 453    2433333.0
# 454     900000.0
# 455    2900000.0
# 456     947276.0
# Name: Salary, Length: 457, dtype: float64

# %%
datas.iloc[20:25,[1,2,3,4,5,6]]
# Out:
#              Team  Number Position  Age  Height  Weight
# 20  Brooklyn Nets      10       SG   22   7-Jun     208
# 21  Brooklyn Nets       6       SG   26   4-Jun     219
# 22  Brooklyn Nets       0       PG   23  11-May     175
# 23  Brooklyn Nets      11        C   28  Jul-00     275
# 24  Brooklyn Nets       1       PF   21  11-Jun     200

# %%
datas.iloc[20:25,[1,2,3,4,5,6]].isnull()
# Out:
#      Team  Number  Position    Age  Height  Weight
# 20  False   False     False  False   False   False
# 21  False   False     False  False   False   False
# 22  False   False     False  False   False   False
# 23  False   False     False  False   False   False
# 24  False   False     False  False   False   False

# %%
datas.iloc[20:25,[1,2,3,4,5,6]].isnull().sum()
# Out:
# Team        0
# Number      0
# Position    0
# Age         0
# Height      0
# Weight      0
# dtype: int64

# %%
datas.iloc[20:25,[1,2,3,4,5,6]].isnull().sum().dropna()
# Out:
# Team        0
# Number      0
# Position    0
# Age         0
# Height      0
# Weight      0
# dtype: int64

# %%
datas.dropna()
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1      Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 3      R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 6    Jordan Mickey  Boston Celtics      55       PF   21   8-Jun     235
# 7     Kelly Olynyk  Boston Celtics      41        C   25  Jul-00     238
# ..             ...             ...     ...      ...  ...     ...     ...
# 449    Rodney Hood       Utah Jazz       5       SG   23   8-Jun     206
# 451  Chris Johnson       Utah Jazz      23       SF   26   6-Jun     206
# 452     Trey Lyles       Utah Jazz      41       PF   20  10-Jun     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26   3-Jun     203
# 456    Jeff Withey       Utah Jazz      24        C   26  Jul-00     231
#
#            College     Salary
# 0            Texas  7730337.0
# ...

# %%
datas.isnull()
# Out:
#       Name   Team  Number  Position    Age  Height  Weight  College  Salary
# 0    False  False   False     False  False   False   False    False   False
# 1    False  False   False     False  False   False   False    False   False
# 2    False  False   False     False  False   False   False    False    True
# 3    False  False   False     False  False   False   False    False   False
# 4    False  False   False     False  False   False   False     True   False
# ..     ...    ...     ...       ...    ...     ...     ...      ...     ...
# 452  False  False   False     False  False   False   False    False   False
# 453  False  False   False     False  False   False   False    False   False
# 454  False  False   False     False  False   False   False     True   False
# 455  False  False   False     False  False   False   False     True   False
# 456  False  False   False     False  False   False   False    False   False
#
# [457 rows x 9 columns]

# %%
datas.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
datas.fillna('SR College',inplace = True)

# %%
datas
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1      Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27   5-Jun     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20  10-Jun     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26   3-Jun     203
# 454      Raul Neto       Utah Jazz      25       PG   24   1-Jun     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26   3-Jul     256
# 456    Jeff Withey       Utah Jazz      24        C   26  Jul-00     231
#
#                College      Salary
# 0                Texas   7730337.0
# ...
