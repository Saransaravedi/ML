# %%
import pandas as pd                            #import the necessary library
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import files
data = files.upload()
# Out:
#      <input type="file" id="files-ea43facc-d430-4cea-af49-fe6659d3ab4b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ea43facc-d430-4cea-af49-fe6659d3ab4b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data
# Out:
# {'02Students.csv': b'Hours,sHours,Marks\r\n0,6,34\r\n1,7,36\r\n1,6,33\r\n1,8,39\r\n1,8,42\r\n2,8,45\r\n2,6,38\r\n3,6,45\r\n3,7,53\r\n3,7,46\r\n3,8,56\r\n4,8,59\r\n4,7,55\r\n4,7,56\r\n5,8,72\r\n5,6,59\r\n6,6,62\r\n6,7,71\r\n7,8,78\r\n7,8,88\r\n7,6,61\r\n7,6,74\r\n8,7,71\r\n8,8,89\r\n9,8,82\r\n9,5,67\r\n9,8,89\r\n10,8,81\r\n10,8,82\r\n11,7,79\r\n'}

# %%
dataset = pd.read_csv("02Students.csv")

# %%
dataset_copy = dataset.copy()                                #shallow copy

# %%
dataset
# Out:
#     Hours  sHours  Marks
# 0       0       6     34
# 1       1       7     36
# 2       1       6     33
# 3       1       8     39
# 4       1       8     42
# 5       2       8     45
# 6       2       6     38
# 7       3       6     45
# 8       3       7     53
# 9       3       7     46
# 10      3       8     56
# 11      4       8     59
# 12      4       7     55
# 13      4       7     56
# 14      5       8     72
# 15      5       6     59
# 16      6       6     62
# 17      6       7     71
# 18      7       8     78
# 19      7       8     88
# 20      7       6     61
# 21      7       6     74
# 22      8       7     71
# 23      8       8     89
# 24      9       8     82
# 25      9       5     67
# 26      9       8     89
# 27     10       8     81
# 28     10       8     82
# 29     11       7     79

# %% [markdown]
# stage 2 Data Pre-Processing
# *EDA(exploratory data analysis)
# *Data cleaning
#      x - independent
#      y- dependent
# *Data Encoding
#       any data type to integer

# %% [markdown]
# EDA

# %%
dataset.shape              # check the number of rows and columns of a data frame
# Out:
# (30, 3)

# %%
dataset.head(7)            # view first 7 records of the data frame    # data sampling view
# Out:
#    Hours  sHours  Marks
# 0      0       6     34
# 1      1       7     36
# 2      1       6     33
# 3      1       8     39
# 4      1       8     42
# 5      2       8     45
# 6      2       6     38

# %%
dataset.tail()            # view ending 5 records of the data frame
# Out:
#     Hours  sHours  Marks
# 25      9       5     67
# 26      9       8     89
# 27     10       8     81
# 28     10       8     82
# 29     11       7     79

# %%
dataset.iloc[20:26]                                                   # data slicing
# Out:
#     Hours  sHours  Marks
# 20      7       6     61
# 21      7       6     74
# 22      8       7     71
# 23      8       8     89
# 24      9       8     82
# 25      9       5     67

# %%
dataset.info()                            # technical enquiry of a data frame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Hours   30 non-null     int64
#  1   sHours  30 non-null     int64
#  2   Marks   30 non-null     int64
# dtypes: int64(3)
# memory usage: 848.0 bytes

# %%
dataset.describe()              # Mini statistical report
# Out:
#            Hours     sHours      Marks
# count  30.000000  30.000000  30.000000
# mean    5.200000   7.100000  61.400000
# std     3.188341   0.922889  17.734828
# min     0.000000   5.000000  33.000000
# 25%     3.000000   6.000000  45.250000
# 50%     5.000000   7.000000  60.000000
# 75%     7.750000   8.000000  77.000000
# max    11.000000   8.000000  89.000000

# %%
dataset.count()
# Out:
# Hours     30
# sHours    30
# Marks     30
# dtype: int64

# %%
dataset.mean()
# Out:
# Hours      5.2
# sHours     7.1
# Marks     61.4
# dtype: float64

# %%
dataset.median()
# Out:
# Hours      5.0
# sHours     7.0
# Marks     60.0
# dtype: float64

# %%
dataset.mode()
# Out:
#    Hours  sHours  Marks
# 0    1.0     8.0     45
# 1    3.0     NaN     56
# 2    7.0     NaN     59
# 3    NaN     NaN     71
# 4    NaN     NaN     82
# 5    NaN     NaN     89
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_0, *['index'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
# ...

# %%
dataset.std()
# Out:
# Hours      3.188341
# sHours     0.922889
# Marks     17.734828
# dtype: float64

# %%
dataset.min()
# Out:
# Hours      0
# sHours     5
# Marks     33
# dtype: int64

# %%
dataset.max()
# Out:
# Hours     11
# sHours     8
# Marks     89
# dtype: int64

# %%
# Data cleaning
dataset.isnull()
# Out:
#     Hours  sHours  Marks
# 0   False   False  False
# 1   False   False  False
# 2   False   False  False
# 3   False   False  False
# 4   False   False  False
# 5   False   False  False
# 6   False   False  False
# 7   False   False  False
# 8   False   False  False
# 9   False   False  False
# 10  False   False  False
# 11  False   False  False
# 12  False   False  False
# 13  False   False  False
# 14  False   False  False
# 15  False   False  False
# 16  False   False  False
# 17  False   False  False
# 18  False   False  False
# 19  False   False  False
# 20  False   False  False
# 21  False   False  False
# 22  False   False  False
# 23  False   False  False
# 24  False   False  False
# 25  False   False  False
# 26  False   False  False
# 27  False   False  False
# 28  False   False  False
# 29  False   False  False

# %%
dataset.isnull().sum()
# Out:
# Hours     0
# sHours    0
# Marks     0
# dtype: int64
